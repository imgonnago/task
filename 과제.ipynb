# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
data = pd.read_csv("C:/dataset_fruit/train_original.csv")

# %%
data.shape
# Out:
# (2207, 184)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207 entries, 0 to 2206
# Columns: 184 entries, ID to 2022-11-28 엽록소
# dtypes: float64(182), int64(1), object(1)
# memory usage: 3.1+ MB

# %%
data.head()
# Out:
#            ID  착과량(int)  수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균  2022-09-01 새순  \
# 0  TRAIN_0000       692  275.0      287.0      292.0  289.5            2.8
# 1  TRAIN_0001       534  293.0      284.0      336.0  310.0            3.3
# 2  TRAIN_0002       634  300.0      392.0      450.0  421.0            3.0
# 3  TRAIN_0003       639  289.0      368.0      379.0  373.5            3.1
# 4  TRAIN_0004       496  306.0      353.0      358.0  355.5            3.7
#
#    2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  ...  2022-11-19 엽록소  \
# 0            2.8            2.7            2.7  ...       70.978249
# 1            3.3            3.3            3.2  ...       71.535483
# 2            2.9            2.9            2.9  ...       71.279804
# 3            3.0            3.0            3.0  ...       69.934615
# 4            3.6            3.6            3.6  ...       68.313016
#
#    2022-11-20 엽록소  2022-11-21 엽록소  2022-11-22 엽록소  2022-11-23 엽록소  \
# ...

# %%
#상관관계 확인

# %%
plt.rc('font', family="Malgum Gothic")
plt.rc('axes', unicode_minus=False)
df = pd.read_csv("C:/dataset_fruit/train.csv")

# %%
target = "착과량(int)"

# %%
corr_with_target = df.corr(numeric_only=True)[target]

# %%
print(corr_with_target.T.to_string())
# Out:
# 착과량(int)          1.000000
# 수고(m)             0.009024
# 수관폭1(min)         0.036663
# 수관폭2(max)         0.047427
# 수관폭평균             0.044030
# 2022-09-01 새순    -0.980677
# 2022-09-02 새순    -0.980713
# 2022-09-03 새순    -0.980599
# 2022-09-04 새순    -0.980550
# 2022-09-05 새순    -0.980510
# 2022-09-06 새순    -0.980892
# 2022-09-07 새순    -0.980706
# 2022-09-08 새순    -0.980145
# 2022-09-09 새순    -0.980319
# 2022-09-10 새순    -0.980702
# 2022-09-11 새순    -0.980293
# 2022-09-12 새순    -0.979811
# 2022-09-13 새순    -0.979935
# 2022-09-14 새순    -0.979887
# 2022-09-15 새순    -0.979699
# 2022-09-16 새순    -0.979884
# 2022-09-17 새순    -0.979393
# 2022-09-18 새순    -0.979190
# 2022-09-19 새순    -0.979435
# 2022-09-20 새순    -0.979581
# 2022-09-21 새순    -0.979242
# 2022-09-22 새순    -0.979141
# 2022-09-23 새순    -0.978966
# 2022-09-24 새순    -0.979232
# 2022-09-25 새순    -0.978716
# 2022-09-26 새순    -0.978628
# 2022-09-27 새순    -0.977892
# 2022-09-28 새순    -0.979015
# 2022-09-29 새순    -0.977841
# ...

# %%
#다중공선성 확인

# %%
multi = df[['수관폭1(min)','수관폭2(max)','수관폭평균']]
multi.head()
multi.shape
# Out:
# (1544, 3)

# %%
corr_matrix = multi.iloc[:,0].corr(multi.iloc[:,1])
print(f"{multi.columns[0]}와 {multi.columns[1]}의 다중공선성: {corr_matrix}")

corr_matrix = multi.iloc[:,0].corr(multi.iloc[:,2])
print(f"{multi.columns[0]}와 {multi.columns[2]}의 다중공선성: {corr_matrix}")

corr_matrix = multi.iloc[:,1].corr(multi.iloc[:,2])
print(f"{multi.columns[1]}와 {multi.columns[2]}의 다중공선성: {corr_matrix}")
# Out:
# 수관폭1(min)와 수관폭2(max)의 다중공선성: 0.8316308503199326
# 수관폭1(min)와 수관폭평균의 다중공선성: 0.9554709515672323
# 수관폭2(max)와 수관폭평균의 다중공선성: 0.9584684302307052

# %%
train_data,test_data = train_test_split(data, test_size = 0.3, random_state=42, shuffle=True)
scaler = StandardScaler()

# %%
train_data.to_csv("C:/dataset_fruit/train.csv", index=False)
test_data.to_csv("C:/dataset_fruit/test.csv", index=False)

# %%
train_df = pd.read_csv("C:/dataset_fruit/train.csv")
test_df = pd.read_csv("C:/dataset_fruit/test.csv")

# %%
#엽록소 컬럼 제거하고 새순 컬럼들을 제곱한 코드
x_train = train_df.drop(['ID','착과량(int)','수관폭1(min)','수관폭2(max)'], axis=1)
x_test = test_df.drop(['ID','착과량(int)','수관폭1(min)','수관폭2(max)'], axis=1)
#shoot으로 train, test 새순 데이터 추출
shoot= x_train.iloc[:, 2:91]#새순 데이터
shoot_test = x_test.iloc[:, 2:91]#새순 데이터
#어차피 수고 수관폭평균, 새순 데이터만 쓸거니까 나머지 컬럼들 다 없애고 새순 컬럼만 추가
x_train = train_df[['수고(m)','수관폭평균']]
x_test = test_df[['수고(m)','수관폭평균']]
#컬럼 이름 추출
shoot_columns = shoot.columns.tolist()
shoot_columns_test = shoot_test.columns.tolist()
#새로 만들 컬럼 생성
shoot_square = pd.DataFrame()
shoot_square_test = pd.DataFrame()
# 새순 컬럼 제곱
for col in shoot_columns:
    shoot_columns = col.replace(' 새순', ' 새순 제곱')
    
    shoot_square[shoot_columns] = shoot[col]**2
    
for col in shoot_columns_test:
    shoot_columns_test = col.replace(' 새순', ' 새순 제곱')
    
    shoot_square_test[shoot_columns_test] = shoot_test[col]**2
# 제곱한 새순 컬럼 concat으로 추가
x_train = pd.concat([x_train, shoot_square], axis=1)
x_test = pd.concat([x_test, shoot_square_test],axis = 1)

# %%
y_train.shape
# Out:
# (1544,)

# %%
y_test.shape
# Out:
# (663,)

# %%
model = RandomForestRegressor(random_state=42)

model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
pred = model.predict(x_test)
mae = mean_absolute_error(y_test, pred)
nmae = mae / np.mean(np.abs(y_test))
print(f" mae value: {mae} / nmae value: {nmae}")
# Out:
#  mae value: 31.881598793363498 / nmae value: 0.07745511176255038
